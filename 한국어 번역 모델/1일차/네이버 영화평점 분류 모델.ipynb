# %% [markdown]
# # torchtext 튜토리얼_한국어

# %% [markdown]
# ## 훈련 데이터와 테스트 데이터 다운

# %%
# 네이버 영화리뷰 데이터 다운
import urllib.request
import pandas as pd

urllib.request.urlretrieve("https://raw.githubusercontent.com/e9t/nsmc/master/ratings_train.txt", filename="ratings_train.txt")
urllib.request.urlretrieve("https://raw.githubusercontent.com/e9t/nsmc/master/ratings_test.txt", filename="ratings_test.txt")
# Out:
# ('ratings_test.txt', <http.client.HTTPMessage at 0x7f4a12d36850>)

# %%
train_df = pd.read_table('ratings_train.txt')
test_df = pd.read_table('ratings_test.txt')

# %%
print('훈련 데이터 샘플의 개수 : {}'.format(len(train_df)))
print('테스트 데이터 샘플의 개수 : {}'.format(len(test_df)))
# Out:
# 훈련 데이터 샘플의 개수 : 150000
# 테스트 데이터 샘플의 개수 : 50000

# %% [markdown]
# ## 필드 정의(torchtext.data)

# %%
! pip install konlpy
# Out:
# Collecting konlpy
#   Downloading konlpy-0.6.0-py2.py3-none-any.whl (19.4 MB)
#      |████████████████████████████████| 19.4 MB 1.9 MB/s
# Requirement already satisfied: numpy>=1.6 in /usr/local/lib/python3.7/dist-packages (from konlpy) (1.19.5)
# Requirement already satisfied: lxml>=4.1.0 in /usr/local/lib/python3.7/dist-packages (from konlpy) (4.2.6)
# Collecting JPype1>=0.7.0
#   Downloading JPype1-1.3.0-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.whl (448 kB)
#      |████████████████████████████████| 448 kB 36.0 MB/s
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.7/dist-packages (from JPype1>=0.7.0->konlpy) (3.10.0.2)
# Installing collected packages: JPype1, konlpy
# Successfully installed JPype1-1.3.0 konlpy-0.6.0

# %%
from torchtext.legacy import data 
from konlpy.tag import Okt

# %%
tokenizer = Okt()

# %%
# 필드 정의
ID = data.Field(sequential = False,
                use_vocab = False) # 실제 사용은 하지 않을 예정

TEXT = data.Field(sequential=True,
                  use_vocab=True,
                  tokenize=tokenizer.morphs, # 토크나이저로는 Mecab 사용.
                  lower=True,
                  batch_first=True,
                  fix_length=20)

LABEL = data.Field(sequential=False,
                   use_vocab=False,
                   is_target=True)

# %% [markdown]
# ## 데이터셋 만들기

# %%
from torchtext.legacy.data import TabularDataset

train_data, test_data =TabularDataset.splits(
     path='.', train='ratings_train.txt', test='ratings_test.txt', format='tsv',
        fields=[('id', ID), ('text', TEXT), ('label', LABEL)], skip_header=True)

# %%
print('훈련 샘플의 개수 : {}'.format(len(train_data)))
print('테스트 샘플의 개수 : {}'.format(len(test_data)))
# Out:
# 훈련 샘플의 개수 : 150000
# 테스트 샘플의 개수 : 50000

# %% [markdown]
# ## 단어 집합 만들기

# %%
TEXT.build_vocab(train_data, min_freq = 10, max_size = 10000)

# %%
print('단어 집합의 크기 : {}'.format(len(TEXT.vocab)))
# Out:
# 단어 집합의 크기 : 10002

# %%
print(TEXT.vocab.stoi)
# Out:
# defaultdict(<bound method Vocab._default_unk_index of <torchtext.legacy.vocab.Vocab object at 0x7f48f205d710>>, {'<unk>': 0, '<pad>': 1, '.': 2, '이': 3, '영화': 4, '의': 5, '..': 6, '가': 7, '에': 8, '을': 9, '...': 10, '도': 11, '들': 12, ',': 13, '는': 14, '를': 15, '은': 16, '너무': 17, '?': 18, '한': 19, '다': 20, '정말': 21, '적': 22, '만': 23, '!': 24, '진짜': 25, '으로': 26, '점': 27, '로': 28, '에서': 29, '연기': 30, '과': 31, '평점': 32, '것': 33, '최고': 34, '내': 35, '~': 36, '나': 37, '그': 38, '잘': 39, '와': 40, '안': 41, '인': 42, '이런': 43, '스토리': 44, '생각': 45, '못': 46, '....': 47, '왜': 48, '드라마': 49, '게': 50, '이다': 51, '감동': 52, '사람': 53, '1': 54, '하는': 55, '보고': 56, '하고': 57, '말': 58, '고': 59, '아': 60, '더': 61, '때': 62, 'ㅋㅋ': 63, '배우': 64, '거': 65, '감독': 66, '그냥': 67, '요': 68, '본': 69, '재미': 70, '내용': 71, '뭐': 72, '중': 73, '까지': 74, '!!': 75, '좀': 76, '쓰레기': 77, '보다': 78, '없는': 79, '시간': 80, '수': 81, '지': 82, '네': 83, '봤는데': 84, '10': 85, '작품': 86, '사랑': 87, '할': 88, '없다': 89, '다시': 90, '하나': 91, '볼': 92, '마지막': 93, '이건': 94, 'ㅋ': 95, '좋은': 96, '저': 97, '정도': 98, '입니다': 99, '같은': 100, '완전': 101, '있는': 102, '2': 103, 'ㅋㅋㅋ': 104, '처음': 105, '장면': 106, '액션': 107, '주인공': 108, '대': 109, '걸': 110, '이렇게': 111, '보는': 112, '개': 113, 'ㅠㅠ': 114, '최악': 115, '3': 116, "'": 117, '지금': 118, '돈': 119, '이야기': 120, '별로': 121, '임': 122, '참': 123, '하': 124, '봐도': 125, '느낌': 126, '연출': 127, '없고': 128, '라': 129, '끝': 130, '명작': 131, '듯': 132, '인데': 133, '별': 134, '그리고': 135, '역시': 136, '기': 137, '난': 138, '많이': 139, '서': 140, '재밌게': 141, '이해': 142, '^^': 143, '!!!': 144, 'ㅡㅡ': 145, '이영화': 146, '면': 147, '라고': 148, '보면': 149, '또': 150, '이나': 151, '여자': 152, '때문': 153, '성': 154, '부터': 155, '전': 156, '해서': 157, '아깝다': 158, '꼭': 159, '편': 160, '된': 161, '이고': 162, '보기': 163, '두': 164, '일': 165, '에게': 166, '여': 167, '짱': 168, '무슨': 169, '기억': 170, '엔': 171, '같다': 172, '결말': 173, '야': 174, 'ㅎㅎ': 175, '랑': 176, '마음': 177, '인생': 178, '소재': 179, 'ㅠ': 180, '~~': 181, '넘': 182, '애': 183, '님': 184, '없이': 185, '수준': 186, '영': 187, '현실': 188, '한다': 189, '해': 190, '씨': 191, '한번': 192, '속': 193, '가장': 194, '반전': 195, '급': 196, '제': 197, '함': 198, '매력': 199, '라는': 200, '전개': 201, ';;': 202, '??': 203, '남자': 204, '한국': 205, '뿐': 206, '가슴': 207, '되는': 208, '하지만': 209, '하게': 210, '알': 211, '음악': 212, '아이': 213, '다른': 214, '니': 215, '원작': 216, '만든': 217, '줄': 218, '인간': 219, '냐': 220, '우리': 221, '추천': 222, '눈물': 223, '않고': 224, '봤다': 225, '합니다': 226, '인지': 227, '모든': 228, '화': 229, '지만': 230, '번': 231, '자체': 232, '하지': 233, '눈': 234, '인가': 235, '캐릭터': 236, '코미디': 237, '솔직히': 238, '좋다': 239, 'ㅋㅋㅋㅋ': 240, '대박': 241, '처럼': 242, '움': 243, '뭔가': 244, '했다': 245, '대한': 246, '모두': 247, '이상': 248, '전혀': 249, '연기력': 250, '여운': 251, '이네': 252, '그래도': 253, '굿': 254, '기대': 255, '있다': 256, '개봉': 257, '근데': 258, '공감': 259, '일본': 260, '아주': 261, '허': 262, '중간': 263, '영상': 264, '표현': 265, ')': 266, '(': 267, '부분': 268, '시리즈': 269, '모습': 270, '자': 271, '그런': 272, '계속': 273, '에는': 274, '이라': 275, '제목': 276, '분': 277, '이랑': 278, '-': 279, '재밌다': 280, 'ㅎ': 281, '작': 282, '가족': 283, '내내': 284, ';': 285, 'oo': 286, '보지': 287, '후': 288, '하면': 289, '뭔': 290, '재미있게': 291, '진심': 292, '없음': 293, '실망': 294, '많은': 295, '봐': 296, '몰입': 297, '건지': 298, '어떻게': 299, '밖에': 300, '기분': 301, '나오는': 302, '였다': 303, '했는데': 304, 'ㅜㅜ': 305, '작가': 306, '봤습니다': 307, '위': 308, '아니다': 309, '이제': 310, '""': 311, '건': 312, '재미없다': 313, '보면서': 314, '않은': 315, ',,': 316, '잼': 317, '공포': 318, '요즘': 319, '용': 320, '아니고': 321, '감': 322, '스릴러': 323, '아니라': 324, '이라는': 325, '점도': 326, '4': 327, '개인': 328, '긴장감': 329, 'ㅡ': 330, '대사': 331, '않는': 332, '조금': 333, '하다': 334, '애니': 335, '이유': 336, '보다가': 337, '삶': 338, '알바': 339, '제대로': 340, '아닌': 341, '특히': 342, '아까운': 343, '노래': 344, '극장': 345, '욕': 346, '딱': 347, '한테': 348, '노잼': 349, '점수': 350, '시작': 351, '0': 352, '막장': 353, '아름다운': 354, '연': 355, '재밌어요': 356, '오랜': 357, '나름': 358, '이란': 359, '.....': 360, '시': 361, '이지': 362, '극': 363, '제일': 364, '차라리': 365, '놈': 366, '좋고': 367, '친구': 368, '에도': 3 ...

# %% [markdown]
# ## 토치 텍스트의 데이터 로더 만들기

# %%
from torchtext.legacy.data import Iterator

# %%
# 하이퍼파라미터
BATCH_SIZE = 128
lr = 0.001
EPOCHS = 10

# %%
train_loader = Iterator(dataset = train_data, batch_size = batch_size)
test_loader = Iterator(dataset = test_data, batch_size = batch_size)

# %%
print('훈련 데이터의 미니 배치 수 : {}'.format(len(train_loader)))
print('테스트 데이터의 미니 배치 수 : {}'.format(len(test_loader)))
# Out:
# 훈련 데이터의 미니 배치 수 : 18750
# 테스트 데이터의 미니 배치 수 : 6250

# %% [markdown]
# ## RNN 모델 구현

# %%
import os
import torch
import torch.nn as nn
import torch.nn.functional as F
from torchtext import data, datasets
import random

# %%
class GRU(nn.Module):
    def __init__(self, n_layers, hidden_dim, n_vocab, embed_dim, n_classes, dropout_p = 0.5):
        super(GRU, self).__init__()
        self.n_layers = n_layers
        self.hidden_dim = hidden_dim

        self.embed = nn.Embedding(n_vocab, embed_dim)
        self.dropout = nn.Dropout(dropout_p)
        self.gru = nn.GRU(embed_dim, self.hidden_dim,
                          num_layers=self.n_layers,
                          batch_first=True)
        self.out = nn.Linear(self.hidden_dim, n_classes)

    def forward(self, x):
        x = self.embed(x)
        h_0 = self._init_state(batch_size=x.size(0)) # 첫번째 히든 스테이트를 0벡터로 초기화
        x,_ = self.gru(x, h_0) # GRU의 리턴값은 (배치크기, 시퀀스 길이, 은닉 상태의 크기)
        h_t = x[:,-1,:] # (배치 크기, 은닉 상태의 크기)의 텐서로 크기가 변경됨. 즉, 마지막 time-step의 은닉 상태만 가져온다.
        self.dropout(h_t)
        logit = self.out(h_t) # (배치 크기, 은닉 상태의 크기) -> 배치 크기기, 출력층의 크기

        return logit

    def _init_state(self, batch_size=1):
        weight = next(self.parameters()).data
        return weight.new(self.n_layers, batch_size, self.hidden_dim).zero_()

# %%
class GRU(nn.Module):
    def __init__(self, n_layers, hidden_dim, n_vocab, embed_dim, n_classes, dropout_p=0.2):
        super(GRU, self).__init__()
        self.n_layers = n_layers
        self.hidden_dim = hidden_dim

        self.embed = nn.Embedding(n_vocab, embed_dim)
        self.dropout = nn.Dropout(dropout_p)
        self.gru = nn.GRU(embed_dim, self.hidden_dim,
                          num_layers=self.n_layers,
                          batch_first=True)
        self.out = nn.Linear(self.hidden_dim, n_classes)

    def forward(self, x):
        x = self.embed(x)
        h_0 = self._init_state(batch_size=x.size(0)) # 첫번째 히든 스테이트를 0벡터로 초기화
        x, _ = self.gru(x, h_0)  # GRU의 리턴값은 (배치 크기, 시퀀스 길이, 은닉 상태의 크기)
        h_t = x[:,-1,:] # (배치 크기, 은닉 상태의 크기)의 텐서로 크기가 변경됨. 즉, 마지막 time-step의 은닉 상태만 가져온다.
        self.dropout(h_t)
        logit = self.out(h_t)  # (배치 크기, 은닉 상태의 크기) -> (배치 크기, 출력층의 크기)
        return logit

    def _init_state(self, batch_size=1):
        weight = next(self.parameters()).data
        return weight.new(self.n_layers, batch_size, self.hidden_dim).zero_()

# %%
vocab_size = len(TEXT.vocab) 
n_classes = 2
print('단어 집합의 크기 : {}'.format(vocab_size))
print('클래스의 개수 : {}'.format(n_classes))
# Out:
# 단어 집합의 크기 : 10002
# 클래스의 개수 : 2

# %%
DEVICE = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model = GRU(1, 256, vocab_size , 128, n_classes, 0.5).to(DEVICE)
optimizer = torch.optim.Adam(model.parameters(), lr=lr)
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-168-03a8bd514330> in <module>()
#       1 DEVICE = torch.device("cuda" if torch.cuda.is_available() else "cpu")
#       2
# ----> 3 model = GRU(1, 256, vocab_size , 128, n_classes, 0.5).to(DEVICE)
#       4 optimizer = torch.optim.Adam(model.parameters(), lr=lr)
#
# /usr/local/lib/python3.7/dist-packages/torch/nn/modules/module.py in to(self, *args, **kwargs)
#     897             return t.to(device, dtype if t.is_floating_point() or t.is_complex() else None, non_blocking)
#     898
# --> 899         return self._apply(convert)
#     900
#     901     def register_backward_hook(
#
# /usr/local/lib/python3.7/dist-packages/torch/nn/modules/module.py in _apply(self, fn)
#     568     def _apply(self, fn):
#     569         for module in self.children():
# --> 570             module._apply(fn)
#     571
#     572         def compute_should_use_set_data(tensor, tensor_applied):
#
# /usr/local/lib/python3.7/dist-packages/torch/nn/modules/module.py in _apply(self, fn)
#     591             # `with torch.no_grad():`
#     592             with torch.no_grad():
# --> 593                 param_applied = fn(param)
#     594             should_use_set_data = compute_should_use_set_data(param, param_applied)
#     595             if should_use_set_data:
#
# /usr/local/lib/python3.7/dist-packages/torch/nn/modules/module.py in convert(t)
#     895                 return t.to(device, dtype if t.is_floating_point() or t.is_complex() else None,
#     896                             non_blocking, memory_format=convert_to_format)
# --> 897             return t.to(device, dtype if t.is_floating_point() or t.is_complex() else None, non_blocking)
#     898
#     899         return self._apply(convert)
#
# RuntimeError: CUDA error: device-side assert triggered
# CUDA kernel errors might be asynchronously reported at some other API call,so the stacktrace below might be incorrect.
# For debugging consider passing CUDA_LAUNCH_BLOCKING=1.

# %%
def train(model, optimizer, train_iter):
    model.train()
    for i, batch in enumerate(train_iter):
        x, y = batch.text.to(DEVICE), batch.label.to(DEVICE)
        
        #y.data.sub_(1) # 레이블 값을 0과 1로 변환
        optimizer.zero_grad()

        logit = model(x)
        y= torch.tensor(y,dtype = torch.long,device =DEVICE)

        loss = F.cross_entropy(logit,y)
        loss.backward()
        optimizer.step()

# %%
def evaluate(model, val_iter):
    """evaluate model"""
    model.eval()
    corrects, total_loss = 0, 0
    for batch in val_iter:
        x, y = batch.text.to(DEVICE), batch.label.to(DEVICE)
        y= torch.tensor(y,dtype = torch.long,device =DEVICE)
        logit = model(x)
        
        loss = F.cross_entropy(logit, y)
        total_loss += loss.item()
        corrects += (logit.max(1)[1].view(y.size()).data == y.data).sum()
    size = len(val_iter.dataset)
    avg_loss = total_loss / size
    avg_accuracy = 100.0 * corrects / size
    return avg_loss, avg_accuracy

# %%
best_val_loss = None
best_model = []
EPOCHS= 10
for e in range(1, EPOCHS + 1 ):
    train(model, optimizer, train_loader)
    val_loss, val_accuracy = evaluate(model, test_loader)

    print("[Epoch: %d] val loss : %5.2f | val accuracy : %5.2f" % (e, val_loss, val_accuracy))

    # 검증 오차가 가장 적은 최적의 모델을 저장
    if not best_val_loss or val_loss < best_val_loss:
        best_val_loss = val_loss
        best_model = model
